# %%
import pandas as pd
import numpy as np

# %%
df_canais = pd.read_csv('C:/Users/daniel.cnunes.SENACRJEDU/Documents/NaraHoteis/canais_venda.csv', sep=';', decimal=',')
df_canais
# Out:
#    id_canal    nome_canal comissao_pct
# 0         1  Site Próprio           8%
# 1         2           ota          18%
# 2         3      Telefone           5%
# 3         4       agencia          12%

# %%
df_clientes = pd.read_csv('C:/Users/daniel.cnunes.SENACRJEDU/Documents/NaraHoteis/clientes.csv', sep=';', decimal=',')
df_clientes
# Out:
#      id_cliente                nome   cidade_origem estado_origem  \
# 0             1         Otavio Reis       São Paulo            SP
# 1             2       Larissa Sousa        Curitiba            SC
# 2             3      Tatiana Coelho  Rio de Janeiro            CE
# 3             4       Wilson Duarte        Brasília            AM
# 4             5       Gabriela Lima  Rio de Janeiro            SP
# ..          ...                 ...             ...           ...
# 296         297       Roberta Leite        Curitiba            DF
# 297         298       Eduardo Lopes       São Paulo            ES
# 298         299  Vanessa Cavalcanti        Curitiba            AM
# 299         300     Julia Monteiro         Brasília            PR
# 300          47         Carlos Neto         Niterói            RJ
#
#     faixa_etaria   tipo_cliente
# 0          18-25             PJ
# 1          18-25  pessoa fisica
# 2            65+    Corporativo
# 3          26-35    corporativo
# ...

# %%
df_funcionarios = pd.read_csv('C:/Users/daniel.cnunes.SENACRJEDU/Documents/NaraHoteis/funcionarios.csv', sep=';', decimal=',')
df_funcionarios
# Out:
#      id_funcionario  id_unidade            nome                cargo  \
# 0                 1           1   Gabriela Lima  Auxiliar de Limpeza
# 1                 2           1    Abel Correia            Segurança
# 2                 3           1   Sara Teixeira  analista financeiro
# 3                 4           1  Julia Monteiro  Auxiliar de Limpeza
# 4                 5           1   Daniela Ramos  Auxiliar de Limpeza
# ..              ...         ...             ...                  ...
# 129             130          12   Fernanda Cruz           Manutenção
# 130             131          12    Abel Correia              Gerente
# 131             132          12     Yuri Castro        Recepcionista
# 132             133          12     Yuri Castro            segurança
# 133             134          12   Eduardo Lopes        Recepcionista
#
#       departamento     salario data_admissao
# 0       Governança  "2.139,00"    2020-10-05
# 1        Segurança  "1.746,00"    2021-12-29
# ...

# %%
df_reserva = pd.read_csv('C:/Users/daniel.cnunes.SENACRJEDU/Documents/NaraHoteis/reservas.csv', sep=';', decimal=',')
df_reserva
# Out:
#       id_reserva  id_unidade  id_tipo_quarto  id_cliente id_canal  \
# 0              1           5               1           3      2.0
# 1              2           5               1         261      4.0
# 2              3          10               4          49      4.0
# 3              4           6               2          23      2.0
# 4              5           7               1          42      1.0
# ...          ...         ...             ...         ...      ...
# 2452        2453          10               3         210      4.0
# 2453        2454           7               3         271      2.0
# 2454        2455           7               1         143      1.0
# 2455        2456           8               4         176      1.0
# 2456        2457           6               3         160      1.0
#
#      data_checkin data_checkout  qtd_diarias  num_hospedes avaliacao_hospede  \
# 0      2024-04-28    2024-04-30            2             1               4.0
# ...

# %%
df_quarto = pd.read_csv('C:/Users/daniel.cnunes.SENACRJEDU/Documents/NaraHoteis/tipos_quarto.csv', sep=';', decimal=',')
df_quarto
# Out:
#    id_tipo_quarto     descricao  capacidade_max valor_diaria_base
# 0               1      STANDARD               2         R$ 280,00
# 1               2     superior                2         R$ 420,00
# 2               3        Deluxe               3         R$ 580,00
# 3               4         Suite               4         R$ 950,00
# 4               5  Suíte Master               4       R$ 1.500,00
# 5               3        Deluxe               3         R$ 580,00

# %%
df_unidades = pd.read_csv('C:/Users/daniel.cnunes.SENACRJEDU/Documents/NaraHoteis/unidades.csv', sep=';')
df_unidades
# Out:
#     id_unidade                   nome_unidade          cidade  \
# 0            1             NaraHoteis Ipanema  Rio de Janeiro
# 1            2     NaraHoteis Barra da Tijuca  Rio de Janeiro
# 2            3              NaraHoteis Centro  Rio de Janeiro
# 3            4        NaraHoteis Santa Teresa  Rio de Janeiro
# 4            5  NaraHoteis Nova Iguaçu Centro     Nova Iguaçu
# 5            6    NaraHoteis Nova Iguaçu Park     Nova Iguaçu
# 6            7          NaraHoteis Petrópolis      Petrópolis
# 7            8         NaraHoteis Teresópolis     Teresópolis
# 8            9            NaraHoteis Friburgo   Nova Friburgo
# 9           10              NaraHoteis Paraty          Paraty
# 10          11      NaraHoteis Angra dos Reis  Angra dos Reis
# 11          12         NaraHoteis Mangaratiba     Mangaratiba
#
#                 regiao categoria_hotel  num_quartos_total
# 0              Capital      5 estrelas               80.0
# ...
